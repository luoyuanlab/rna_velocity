# %%
import scvelo as scv
import scanpy as sc
import pickle as pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import celldancer as cd
import celldancer.cdplt as cdplt
from celldancer.cdplt import colormap
from celldancer.utilities import export_velocity_to_dynamo
import celldancer.utilities as cdutil

# %% [markdown]
# ## Gastrulation erythroid

# %%
import pytorch_lightning as pl
trainer = pl.Trainer(progress_bar_refresh_rate=0)
trainer = pl.Trainer(enable_progress_bar=False)

#adata = sc.read_h5ad('../Data/gastrulation_erythroid.h5ad')
adata = sc.read_h5ad('/share/fsmresfiles/lyw/Singlecell/RNAVelocity/scvelo_examples/gastrulation_erythroid/gastrulation_erythroid.h5ad')
scv.pp.filter_and_normalize(adata, min_shared_counts=20, n_top_genes=3000)
scv.pp.moments(adata, n_pcs=30, n_neighbors=30)

input_data = cdutil.adata_to_df_with_embed(adata,
                                  us_para=['Mu','Ms'],
                                  cell_type_para='celltype',
                                  embed_para='X_umap',
                                  save_path='../cellDancer_result/cell_type_u_s_GE.csv')
loss_df, cellDancer_df=cd.velocity(input_data,
                                   gene_list= np.array(input_data['gene_name']),
                                   permutation_ratio=0.125,
                                   n_jobs=-1)

cellDancer_df=cd.compute_cell_velocity(cellDancer_df=cellDancer_df, projection_neighbor_choice='gene', 
                                        expression_scale='power10', projection_neighbor_size=10, speed_up=(100,100))
adata = export_velocity_to_dynamo(cellDancer_df, adata)

adata.layers['velocity_S'] = adata.layers['velocity_S'].A
scv.tl.velocity_graph(adata, vkey='velocity_S', n_jobs=-1)
scv.tl.velocity_embedding(adata, basis='umap', vkey='velocity_S')
#fix, ax = plt.subplots(1, 1, figsize = (8, 6))
#scv.pl.velocity_embedding_stream(adata1, basis='umap', save = False, vkey='velocity_S', color='celltype', title='scVelo_dynamical', fontsize=20, show = False, ax = ax, legend_fontsize = 15)
#plt.savefig('../Gastrulation_Erythroid_Results/cellDancer_UMAP_stream.png', dpi=80)
#adata.write_h5ad('../Gastrulation_Erythroid_Results/cellDancer.h5ad')
# Out:
# /home/ylz0045/software/anaconda3.9/envs/cellDancer/lib/python3.7/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:91: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   f"Setting `Trainer(progress_bar_refresh_rate={progress_bar_refresh_rate})` is deprecated in v1.5 and"
# Filtered out 47456 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 3000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:03) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:04) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# 100%|██████████████████████████████████████████████████████████████████████████████| 3000/3000 [04:39<00:00, 10.73it/s]
# Using /home/ylz0045/Singlecell/RNAVelocity/our_perspective_TME_simulation/Github/benchmark/cellDancer_velocity_2025-10-30 20-10-06 as the output path.
# Arranging genes for parallel job.
# 3000  genes were arranged to  63  portions.
# Velocity Estimation:   0%|          | 0/63 [00:00<?, ?it/s]
# Velocity Estimation:   2%|▏         | 1/63 [00:46<48:27, 46.89s/it]
# Velocity Estimation:   3%|▎         | 2/63 [01:17<37:56, 37.32s/it]
# Velocity Estimation:   5%|▍         | 3/63 [01:44<32:40, 32.67s/it]
# Velocity Estimation:   6%|▋         | 4/63 [02:14<31:07, 31.66s/it]
# Velocity Estimation:   8%|▊         | 5/63 [02:44<29:53, 30.93s/it]
# Velocity Estimation:  10%|▉         | 6/63 [03:15<29:21, 30.90s/it]
# Velocity Estimation:  11%|█         | 7/63 [03:45<28:42, 30.76s/it]
# Velocity Estimation:  13%|█▎        | 8/63 [04:11<26:51, 29.30s/it]
# Velocity Estimation:  14%|█▍        | 9/63 [04:41<26:24, 29.35s/it]
# Velocity Estimation:  71%|███████▏  | 45/63 [23:20<09:12, 30.69s/it]
# Velocity Estimation:  73%|███████▎  | 46/63 [23:50<08:38, 30.52s/it]
# Velocity Estimation:  75%|███████▍  | 47/63 [24:23<08:19, 31.19s/it]
# Velocity Estimation:  76%|███████▌  | 48/63 [24:54<07:44, 30.97s/it]
# Velocity Estimation:  78%|███████▊  | 49/63 [25:23<07:04, 30.32s/it]
# Velocity Estimation:  79%|███████▉  | 50/63 [25:55<06:42, 30.95s/it]
# Velocity Estimation:  81%|████████  | 51/63 [26:27<06:16, 31.34s/it]
# Velocity Estimation:  83%|████████▎ | 52/63 [26:58<05:42, 31.13s/it]
# Velocity Estimation:  84%|████████▍ | 53/63 [27:30<05:14, 31.45s/it]
# Velocity Estimation:  86%|████████▌ | 54/63 [28:01<04:42, 31.35s/it]
# Velocity Estimation:  87%|████████▋ | 55/63 [28:32<04:09, 31.18s/it]
# Velocity Estimation:  89%|████████▉ | 56/63 [29:04<03:39, 31.36s/it]
# Velocity Estimation:  90%|█████████ | 57/63 [29:35<03:07, 31.27s/it]
# Velocity Estimation:  92%|█████████▏| 58/63 [30:08<02:38, 31.71s/it]
# Velocity Estimation:  94%|█████████▎| 59/63 [30:38<02:04, 31.20s/it]
# Velocity Estimation:  95%|█████████▌| 60/63 [31:09<01:33, 31.14s/it]
# Velocity Estimation:  97%|█████████▋| 61/63 [31:41<01:02, 31.50s/it]
# Velocity Estimation:  98%|█████████▊| 62/63 [32:12<00:31, 31.35s/it]
# Velocity Estimation: 100%|██████████| 63/63 [32:29<00:00, 26.96s/it]
#                                                                                                                        Not predicted gene list:['Spp1', 'Gzmf', 'Nkg7', 'Gzmg']. Try visualizing the unspliced and spliced columns of the gene(s) to check the quality.
# computing velocity graph (using 48/48 cores)
#     finished (0:00:33) --> added
#     'velocity_S_graph', sparse matrix with cosine correlations (adata.uns)
# computing velocity embedding
#     finished (0:00:04) --> added
#     'velocity_S_umap', embedded velocity vectors (adata.obsm)

# %% [markdown]
# ## Dentate Gyrus neurogenesis

# %%
import pytorch_lightning as pl
trainer = pl.Trainer(progress_bar_refresh_rate=0)
trainer = pl.Trainer(enable_progress_bar=False)

adata = sc.read_h5ad('../Data/DentateGyrus_10X43_1.h5ad')
scv.pp.filter_and_normalize(adata, min_shared_counts=20, n_top_genes=3000)
scv.pp.moments(adata, n_pcs=30, n_neighbors=30)

input_data = cdutil.adata_to_df_with_embed(adata,
                                  us_para=['Mu','Ms'],
                                  cell_type_para='clusters',
                                  embed_para='X_umap',
                                  save_path='../cellDancer_result/cell_type_u_s_DGN.csv')
loss_df, cellDancer_df=cd.velocity(input_data,
                                   gene_list= np.array(input_data['gene_name']),
                                   permutation_ratio=0.125,
                                   n_jobs=-1, save_path=None)

cellDancer_df=cd.compute_cell_velocity(cellDancer_df=cellDancer_df, projection_neighbor_choice='gene', 
                                        expression_scale='power10', projection_neighbor_size=10, speed_up=(100,100))
adata = export_velocity_to_dynamo(cellDancer_df, adata)

adata.layers['velocity_S'] = adata.layers['velocity_S'].A
scv.tl.velocity_graph(adata, vkey='velocity_S', n_jobs=-1)
scv.tl.velocity_embedding(adata, basis='umap', vkey='velocity_S')
fix, ax = plt.subplots(1, 1, figsize = (8, 6))
scv.pl.velocity_embedding_stream(adata1, basis='umap', save = False, vkey='velocity_S', color='clusters', title='cellDancer', fontsize=20, show = False, ax = ax, legend_fontsize = 15)
plt.savefig('../Dentate_Gyrus_Results/cellDancer_UMAP_stream.png', dpi=80)
adata.write_h5ad('../Dentate_Gyrus_Results/cellDancer.h5ad')
# Out:
# /home/ylz0045/software/anaconda3.9/envs/cellDancer/lib/python3.7/site-packages/pytorch_lightning/trainer/connectors/callback_connector.py:91: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=0)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   f"Setting `Trainer(progress_bar_refresh_rate={progress_bar_refresh_rate})` is deprecated in v1.5 and"
# Filtered out 10340 genes that are detected 20 counts (shared).
# Normalized count data: X, spliced, unspliced.
# Extracted 3000 highly variable genes.
# Logarithmized X.
# computing neighbors
#     finished (0:00:00) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# 100%|██████████████████████████████████████████████████████████████████████████████| 3000/3000 [01:23<00:00, 35.82it/s]
# Using /home/ylz0045/Singlecell/RNAVelocity/our_perspective_TME_simulation/Github/benchmark/cellDancer_velocity_2025-10-30 19-44-08 as the output path.
# Arranging genes for parallel job.
# 3000  genes were arranged to  63  portions.
# Velocity Estimation:   0%|          | 0/63 [00:00<?, ?it/s]
# Velocity Estimation:   2%|▏         | 1/63 [00:26<27:33, 26.66s/it]
# Velocity Estimation:   3%|▎         | 2/63 [00:39<18:39, 18.35s/it]
# Velocity Estimation:   5%|▍         | 3/63 [00:51<15:39, 15.66s/it]
# Velocity Estimation:   6%|▋         | 4/63 [01:03<13:55, 14.16s/it]
# Velocity Estimation:   8%|▊         | 5/63 [01:14<12:41, 13.12s/it]
# Velocity Estimation:  10%|▉         | 6/63 [01:25<11:47, 12.40s/it]
# Velocity Estimation:  11%|█         | 7/63 [01:38<11:36, 12.43s/it]
# Velocity Estimation:  13%|█▎        | 8/63 [01:51<11:28, 12.53s/it]
# Velocity Estimation:  14%|█▍        | 9/63 [02:03<11:12, 12.45s/it]
# Velocity Estimation:  16%|█▌        | 10/63 [02:15<11:02, 12.49s/it]
# Velocity Estimation:  17%|█▋        | 11/63 [02:27<10:40, 12.32s/it]
# Velocity Estimation:  19%|█▉        | 12/63 [02:38<10:03, 11.83s/it]
# Velocity Estimation:  21%|██        | 13/63 [02:50<10:00, 12.02s/it]
# Velocity Estimation:  22%|██▏       | 14/63 [03:02<09:46, 11.98s/it]
# Velocity Estimation:  24%|██▍       | 15/63 [03:14<09:26, 11.81s/it]
# Velocity Estimation:  25%|██▌       | 16/63 [03:26<09:25, 12.02s/it]
# Velocity Estimation:  27%|██▋       | 17/63 [03:38<09:09, 11.94s/it]
# Velocity Estimation:  29%|██▊       | 18/63 [03:50<08:55, 11.91s/it]
# Velocity Estimation:  30%|███       | 19/63 [04:01<08:37, 11.75s/it]
# Velocity Estimation:  32%|███▏      | 20/63 [04:13<08:24, 11.73s/it]
# Velocity Estimation:  33%|███▎      | 21/63 [04:25<08:21, 11.94s/it]
# Velocity Estimation:  35%|███▍      | 22/63 [04:37<08:07, 11.88s/it]
# Velocity Estimation:  37%|███▋      | 23/63 [04:49<07:52, 11.80s/it]
# Velocity Estimation:  38%|███▊      | 24/63 [05:00<07:29, 11.54s/it]
# Velocity Estimation:  95%|█████████▌| 60/63 [12:07<00:32, 10.86s/it]
# Velocity Estimation:  97%|█████████▋| 61/63 [12:19<00:22, 11.10s/it]
# Velocity Estimation:  98%|█████████▊| 62/63 [12:30<00:11, 11.09s/it]
# Velocity Estimation: 100%|██████████| 63/63 [12:38<00:00, 10.42s/it]
#                                                                                                                        Not predicted gene list:['Acta2', 'Crip1']. Try visualizing the unspliced and spliced columns of the gene(s) to check the quality.
# computing velocity graph (using 48/48 cores)
# WARNING: Unable to create progress bar. Consider installing `tqdm` as `pip install tqdm` and `ipywidgets` as `pip install ipywidgets`,
# or disable the progress bar using `show_progress_bar=False`.
#     finished (0:00:05) --> added
#     'velocity_S_graph', sparse matrix with cosine correlations (adata.uns)
# computing velocity embedding
#     finished (0:00:01) --> added
#     'velocity_S_umap', embedded velocity vectors (adata.obsm)

# %% [markdown]
# ## Simulated data

# %%
import pytorch_lightning as pl
trainer = pl.Trainer(progress_bar_refresh_rate=0)
trainer = pl.Trainer(enable_progress_bar=False)

adata = sc.read_h5ad('../Data/simulated_T_cell.h5ad')
adata.obsm['X_umap'] = pickle.load(open('../Data/UMAP.pkl','rb'))
scv.pp.moments(adata, n_neighbors=30)

input_data = cdutil.adata_to_df_with_embed(adata,
                                  us_para=['Mu','Ms'],
                                  cell_type_para='T_area',
                                  embed_para='X_umap',
                                  save_path='../cellDancer_result/cell_type_u_s_simu.csv')
loss_df, cellDancer_df=cd.velocity(input_data,
                                   gene_list= np.array(input_data['gene_name']),
                                   permutation_ratio=0.125,
                                   n_jobs=1)

cellDancer_df=cd.compute_cell_velocity(cellDancer_df=cellDancer_df, projection_neighbor_choice='gene', 
                                        expression_scale='power10', projection_neighbor_size=10, speed_up=(100,100))
adata = export_velocity_to_dynamo(cellDancer_df, adata)

adata.layers['velocity_S'] = adata.layers['velocity_S'].A
scv.tl.velocity_graph(adata, vkey='velocity_S', n_jobs=-1)
scv.tl.velocity_embedding(adata, basis='umap', vkey='velocity_S')
fix, ax = plt.subplots(1, 1, figsize = (8, 6))
scv.pl.velocity_embedding_stream(adata, basis='umap', save = False, vkey='velocity_S', color='time', title='cellDancer', fontsize=20, show = False, ax = ax, legend_fontsize = 15)
plt.savefig('../Simulation_Results/cellDancer_UMAP_stream.png', dpi=80)
adata.write_h5ad('../Simulation_Results/cellDancer.h5ad')
# Out:
# computing neighbors
#     finished (0:00:14) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)
# computing moments based on connectivities
#     finished (0:00:00) --> added
#     'Ms' and 'Mu', moments of un/spliced abundances (adata.layers)
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 46.32it/s]
# Using /home/ylz0045/Singlecell/RNAVelocity/our_perspective_TME_simulation/Github/benchmark/cellDancer_velocity_2025-10-30 00-35-02 as the output path.
# Arranging genes for parallel job.
# 3  genes were arranged to  3  portions.
# Velocity Estimation:   0%|          | 0/3 [00:00<?, ?it/s]
# Velocity Estimation:  33%|███▎      | 1/3 [00:03<00:07,  3.73s/it]
# Velocity Estimation:  67%|██████▋   | 2/3 [00:07<00:03,  3.74s/it]
# Velocity Estimation: 100%|██████████| 3/3 [00:11<00:00,  3.85s/it]
# computing velocity graph (using 48/48 cores)
# WARNING: Unable to create progress bar. Consider installing `tqdm` as `pip install tqdm` and `ipywidgets` as `pip install ipywidgets`,
# or disable the progress bar using `show_progress_bar=False`.
#     finished (0:00:09) --> added
#     'velocity_S_graph', sparse matrix with cosine correlations (adata.uns)
# computing velocity embedding
#     finished (0:00:01) --> added
#     'velocity_S_umap', embedded velocity vectors (adata.obsm)
